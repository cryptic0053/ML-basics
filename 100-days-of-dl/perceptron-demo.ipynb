# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
print(df.shape)
df.head()
# Out:
# (100, 4)
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
sns.scatterplot(x=df['cgpa'],y=df['iq'],hue=df['placement'])
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[11., 47.]])

# %%
p.intercept_
# Out:
# array([-72.])

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in e:\anaconda\envs\cryptic\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in e:\anaconda\envs\cryptic\lib\site-packages (from mlxtend) (2.2.4)
# Requirement already satisfied: pandas>=0.24.2 in e:\anaconda\envs\cryptic\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in e:\anaconda\envs\cryptic\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in e:\anaconda\envs\cryptic\lib\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in e:\anaconda\envs\cryptic\lib\site-packages (from mlxtend) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\envs\cryptic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\cryptic\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\cryptic\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\cryptic\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda\envs\cryptic\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Using cached mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values, y.values, clf=p, legend=2)
# Out:
# e:\Anaconda\envs\cryptic\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
